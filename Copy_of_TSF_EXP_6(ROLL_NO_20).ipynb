# %% [markdown]
# <a href="https://colab.research.google.com/github/shrutiiiyadav/-_-1-IRIS-FLOWER-CLASSIFICATION/blob/main/Copy_of_TSF_EXP_6(ROLL_NO_20).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **NAME:** Shruti Yadav
#
# **ROLL NO:** 20
#
# **Experiment No. 6 : **
# Implementation of Moving Average time analysis data and Smoothing the
# Time analysis Data
#
# **Maximum Marks:** 10
#
#
# **Experimentation:**
#
# 1. Understand the concept and implementation of moving averages
# 2. Learn methods for smoothing time series data

# %%
import seaborn as sns

# %%
df = sns.load_dataset('flights')

# %%
df
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]

# %%
df.info
# Out:
# <bound method DataFrame.info of      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]>

# %%
df['year'] = df['year'].astype(str)
df['month'] = df['month'].astype(str)
df['date'] = df['year'].astype(str) + df['month']
df.drop(['year','month'],axis=1,inplace=True)

# %%
df
# Out:
#      passengers     date
# 0           112  1949Jan
# 1           118  1949Feb
# 2           132  1949Mar
# 3           129  1949Apr
# 4           121  1949May
# ..          ...      ...
# 139         606  1960Aug
# 140         508  1960Sep
# 141         461  1960Oct
# 142         390  1960Nov
# 143         432  1960Dec
#
# [144 rows x 2 columns]

# %%
import pandas as pd
print(df['date'].head())
# Out:
# 0    1949Jan
# 1    1949Feb
# 2    1949Mar
# 3    1949Apr
# 4    1949May
# Name: date, dtype: object

# %%
df['date'] = pd.to_datetime(df['date'],format="%Y%b")

# %%
df
# Out:
#      passengers       date
# 0           112 1949-01-01
# 1           118 1949-02-01
# 2           132 1949-03-01
# 3           129 1949-04-01
# 4           121 1949-05-01
# ..          ...        ...
# 139         606 1960-08-01
# 140         508 1960-09-01
# 141         461 1960-10-01
# 142         390 1960-11-01
# 143         432 1960-12-01
#
# [144 rows x 2 columns]

# %%
df.set_index('date',inplace=True)

# %%
df
# Out:
#             passengers
# date
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %%
df.rolling(3).mean()
# Out:
#             passengers
# date
# 1949-01-01         NaN
# 1949-02-01         NaN
# 1949-03-01  120.666667
# 1949-04-01  126.333333
# 1949-05-01  127.333333
# ...                ...
# 1960-08-01  587.666667
# 1960-09-01  578.666667
# 1960-10-01  525.000000
# 1960-11-01  453.000000
# 1960-12-01  427.666667
#
# [144 rows x 1 columns]

# %%
df.expanding().mean()
# Out:
#             passengers
# date
# 1949-01-01  112.000000
# 1949-02-01  115.000000
# 1949-03-01  120.666667
# 1949-04-01  122.750000
# 1949-05-01  122.400000
# ...                ...
# 1960-08-01  275.514286
# 1960-09-01  277.163121
# 1960-10-01  278.457746
# 1960-11-01  279.237762
# 1960-12-01  280.298611
#
# [144 rows x 1 columns]

# %%
df.ewm(span=2).mean()
# Out:
#             passengers
# date
# 1949-01-01  112.000000
# 1949-02-01  116.500000
# 1949-03-01  127.230769
# 1949-04-01  128.425000
# 1949-05-01  123.454545
# ...                ...
# 1960-08-01  598.995389
# 1960-09-01  538.331796
# 1960-10-01  486.777265
# 1960-11-01  422.259088
# 1960-12-01  428.753029
#
# [144 rows x 1 columns]
